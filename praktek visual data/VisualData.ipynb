# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['Januari', 'Februari', 'Maret', 'April', 'Mei', 'Juni', 'Juli', 'Agustus', 'September', 'Oktober', 'November', 'Desember']

#Pengeluaran antara 500.000 - 2.000.000

Minggu_1 = np.random.randint(500000,2000001,12)
Minggu_2 = np.random.randint(500000,2000001,12)
Minggu_3 = np.random.randint(500000,2000001,12)
Minggu_4 = np.random.randint(500000,2000001,12)

data = {
    'Bulan' : bulan,
    'Minggu_1' : Minggu_1,
    'Minggu_2' : Minggu_2,
    'Minggu_3' : Minggu_3,
    'Minggu_4' : Minggu_4
}

df = pd.DataFrame(data)

df['Total_Pengeluaran'] = df[['Minggu_1', 'Minggu_2', 'Minggu_3', 'Minggu_4']].sum(axis=1)
df
# Out:
#         Bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total_Pengeluaran
# 0     Januari   1432585    695528    683241   1546305            4357659
# 1    Februari   1941297   1942580    573092   1189446            5646415
# 2       Maret    681007   1386731    913680   1684089            4665507
# 3       April    998241   1029098   1482282   1549637            5059258
# 4         Mei   1416355   1679771   1955402   1125343            6176871
# 5        Juni   1641479   1592078   1350143   1383374            5967074
# 6        Juli    977156   1618056    515421   1787733            4898366
# 7     Agustus   1594694   1807000    647578   1702018            5751290
# 8   September    946155    613072    878166   1531152            3968545
# 9     Oktober   1774258   1570137    577600   1801345            5723340
# 10   November    961093   1748351    714530    841131            4265105
# 11   Desember   1108995   1322195    813821   1464460            4709471

# %%
#Total pengeluaran PEr Bulan -> BAR

plt.figure(figsize=(12,6)) #Canvas dengan ukuran width,height (inch)
plt.title('Total Pengeluaran Per Bulan')
plt.bar(df['Bulan'],df['Total_Pengeluaran'],color='skyblue')
plt.xticks(rotation=45)
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#Scatter plot untuk analisa data pengeluaran per minggu per bulan

plt.figure(figsize=(12,6))
for minggu in ['Minggu_1', 'Minggu_2', 'Minggu_3', 'Minggu_4']:
    plt.plot(df['Bulan'], df[minggu], marker = 'o', label  = minggu)

plt.title('Pengeluaran Per Minggu')
plt.xlabel('Bulan')
plt.ylabel('Pengeluaran(Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie Chart -> Prosentase
plt.figure(figsize = (6,6))
plt.pie(df['Total_Pengeluaran'], labels = df['Bulan'], startangle = 90, autopct = '%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1,13)

x = df[['Bulan_Angka']]
y = df['Total_Pengeluaran']

model = LinearRegression()

model.fit(x,y)

prediksi = model.predict([[13]])[0]
print(f"Hasil Prediksi adalah : {prediksi:,.0f}")
# Out:
# Hasil Prediksi adalah : 4,895,529
# C:\Users\adihe\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
